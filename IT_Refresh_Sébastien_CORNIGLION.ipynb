# %% [markdown]
# ## Day1

# %% [markdown]
# **What is a computer?** \
# Data(Numerical)
# Turung Machine; step by step read(Fetch) \
#
# `Turning Machine` expects a known "Grammer" \
# ←[Hard Coded ](https://en.wikipedia.org/wiki/Hard_coding)\
# Language Theory - how the action is processed \
# A `Deterministic Machine` - How to deal with the randomeness \

# %% [markdown]
# ![Turing Machine.png](data:image/png;base64,...)

# %% [markdown]
# [The von Neumann Architecture](https://en.wikipedia.org/wiki/Von_Neumann_architecture) \
#
# `ALU`: Arithmetics & logic unit \
# `Main Memory` \
# ←Volatile: very fast \
# `Secondary Storage`(Persistant Storage) \
# ← Hard Drive \
# Secondary \
#
# `Hibernation` by Microsoft - Data photograph to store the memory and use when the computer is powered on \
#
# You need to have the large [bus](https://en.wikipedia.org/wiki/Bus_(computing)) so that GPU can run first as well \
# RAM is traded and seen as the financial commodity
# RAM read and write
# ROM only read \
# Bus is related to Bus. CPU has a bus requirement \
# Type of bus and type of cpu is stricted to the certain type of GPU \
# PCIE Bus \
#
# \

# %% [markdown]
# ![The von Neumann Architecture.png](data:image/png;base64,...)

# %% [markdown]
# When under voltage, a CPU runs the following instruction(hard-wired behavior) \
#
# `NOP` → No Operation (Infinitely) \
#
# **When you turn on the PC, CPU is pre-made to do nothing** \
#
# ~ Question ~ \
# >How do we get out of the state of "NOP" ?? \
#
# ~ Answer ~ \
# > Interrupt with the Hardware \
# Stopping/Halting a CPU \
# Hardware Component: `PIC` (Programmable Transpition Controller) \
# * Connected to CPU via BUS  \
# * can halt CPU and provide another instruction \
# * changes the value of INSTRUCTION pointer of CPU \
#
# [`BIOS`](https://whatis.techtarget.com/definition/BIOS-basic-input-output-system#:~:text=BIOS%20(basic%20input%2Foutput%20system)%20is%20the%20program%20a,%2C%20keyboard%2C%20mouse%20and%20printer.) \
# PIC sets Instruction pointer of CPU to the first main memory position of the basic Input/Output sub-system/sub-routines  \
# * **Executable computer program in ROM: Read only memory** \
# * Program can provide the layer of input and output system

# %% [markdown]
# First Look in a CPU \
#
# Inside the chip: \
# * [`Arithematic an logic unit(ALU)`](https://en.wikipedia.org/wiki/Arithmetic_logic_unit#:~:text=In%20computing%2C%20an%20arithmetic%20logic,operates%20on%20floating%20point%20numbers.) \
# Boolean Algebra in base 2: Values: 0 & 1 \
# * [`Registers`](https://en.wikipedia.org/wiki/Processor_register): Volatile Memory inside the CPU ←They are extremely fast(As fast as CPU)\
# Unique location in a whole system where computation are performed \
# Tiny Space: ~32/64/128/256 kilo Bytes ←Registers with 32 binary positions \
#
# Two Main Types Registers:
# * `General Purpose Registers`: EAX, EBX, ECX.... \
# * `Specific Purpose Registers`: Instruction Pointer(IP) →the next memory location to read/fetch \
#
# **Regardless of purpose, base 2 integer value** \
# 32 bit CPU = registeres with 32 binary positions \
#
#
# ~ memo ~ \
# > you change the instruction pointer to read the next statement← [`High Level programming language`](https://en.wikipedia.org/wiki/High-level_programming_language)
#
# Low Level
# - directly executable
# - complete control
# - very efficient
# - great for OS/ Firmware
# - difficult to use
# - longer development time
#
# High Level
# - Java, PHP, C#, Swift
# - COBOL, Fortran
# - Functions, object garbage collector
# - Abstraction
#
#
# How much RAM can you address depending on the size of Processor \
#
# Main Memory: \
# `FLAT VECTOR`(Human representation) \
# 32 bit 2^32 -1 \
# 62 bit 2^64 -1 \
# CPU bitness(register size) imposes the limit of Maximum RAM useable \
#
# ~ memo ~
#
# >Python 3, There is no virtual limit on the size of integer \
# As long as Python 3 allows, the amount which can be processed is limitless \
# Python 2 was limited to the size of your CPU \

# %% [markdown]
# **Basic Input/Output subsystem(BIOS)** \
# (updated to [`EFI`](https://en.wikipedia.org/wiki/EFI_system_partition), same principles) \
#
# Provides: Output of progress on Monitor \
# >Allows uses input(keyboards,...) \
# use of secondary Memory(storage) \
# → Searches for a bootable `operating system` \
#
# Undecidabity problem: \
# >The "OS load" must start but how? where? which operating system? \
#
# Storage organisation: \
# >Hardware + Software Formatting
#
# Close link to how secondary memory is organised ←Filesystem Format \

# %% [markdown]
# ![link text](https://upload.wikimedia.org/wikipedia/commons/f/f8/Laptop-hard-drive-exposed.jpg)

# %% [markdown]
# [`Bootloader`](https://en.wikipedia.org/wiki/Booting) \
# ~ momo ~
# > BIOS will look for known advanced physical hard drive ←Magic Sectors \
# >Master Boot Record→Value of another sector \
# >Location MBA is fixed and BIOS go and read the MBA which start the Boot loader
#
# Reads [`MBR`](https://en.wikipedia.org/wiki/Master_boot_record): \
# Go and read Bootloader at value of MBR　\
# → Loads bootloader(software) in main memory \
#
# ~ memo ~
# > ・　Downloding multiple OS system on one PC is very dangerous \
# ・　Microsoft being Microsoft \
# ・　Windows and Linux → Windows first then Linux so that Linux can replace the Bootloader for the one in Windows and MBA value is changed
#
#
# After Bootloading \
# Load of the operating system \
# the OS `Kernel` \
# * Lowest layer of software on top of Hardware

# %% [markdown]
# ![Kernel.png](data:image/png;base64,...)

# %% [markdown]
# `OS Kernel`: 3 mandatory lectures \
# 1) Hardware ressources appropriation \
#   * Kernel become the owner of everything "owns " CPU, BUS, RAM, I/O(BUS), Storage \
#
# 2) [Scheduling](https://en.wikipedia.org/wiki/Scheduling_(computing)) (when to give the HW) \
#  * Which program to run, which program to halt
#
# 3) Inter Process Communication(IPC)
#  * written by operating system vendor Data Exchange \
#
# Once the kernel has loaded, it is programmed to follows the load of all other required components \
#
# Two major Kernel Designs \
# [`Monolithic kernel`](https://en.wikipedia.org/wiki/Monolithic_kernel#:~:text=A%20monolithic%20kernel%20is%20an,virtual%20interface%20over%20computer%20hardware.): Driver's code is loaded in kernel space in kernel memory space + priviledges ← Very good input and output \
# `Micro-Kernel`: Drivers one in user-space loaded with, lower priviledges ex)Linax Kernel, Unix, Apple \
#  `Hybrid`: windows divides in kernel space \
#
#  Ok, shell of OS is loaded and available to use. How is a new program loaded? \
#  The shell must: \
# * Ask the kernel to capitate its existence in RAM → new PID 351
# * exec(path-target-excutable) "C:/windows/system32/div・exe" →Replace binary code in RAM \
# Linax, only pure command shell. That's all \
# You need to have a shell to use the OS. Shell is the user interface. \
# Its python interpreter duplicate itself

# %% [markdown]
# ~ memo ~
# >You must increase the performance of Bus \
# `Graphic Card` is very large registers and because it is bigger, it performs better for Linear Algebra. This is happening in 200 bytes. We must use the Bus multiple times \
#
# [`Clock`](https://www.computerhope.com/jargon/c/clock.htm#:~:text=1.,speed%20of%20all%20computer%20functions.&text=The%20speed%20of%20a%20computer,%2C%20or%20vibrations%2C%20a%20second.): How many per second you can iterate the process. \
#
# Provides:
# Output of progress on Monitor \
# uses input (keyboard) \
# Use of secondary Memory(shortage)

# %% [markdown]
# ## Day2

# %% [markdown]
# Process P1 with "folk" mechanism is re \
#
# P1 runs, it's "tape" is being read by the Turing Machine \
#
# folk sends a "message" to the kernel
# → Kernel code must execute \
# The "tape" must be changed \
#
# The need for multi-process operating systems \
# Each running program(including the kernel) compete to obtain access to hardware ressources chiefly for CPU, RAM, BUS→I/O \
#
# We need to shedule them \
#
# \
#
# The `Schedular` \
# Code located in the kernel \
# → The schedular code need to run regularly \
# → To be defined \
#
# **Two models of multi-testing** \
# 1)Cooperative Multi-Tasking \
# >Simple to implement: Every program are "nice", their code release H/W ressources using a sleep(t) function for time being \
# Pros: the running program runs all hardware ressources \
# Cons: Program need to play "nice" \
# Ex)Adobe Photoshop gather all the resources and not being cooperative
#
# 2) Preemptive Multi-Tasking \
# >The schedular(the kernel) become the master conductor of programs execution schedule \
# The scheduler must be able to HALT pre-empt the execution of any given winning program \
#
# >**Scheduler and PIC** \
# When kernel loads, it sets a position of where in RAM(main memory), the executable code of Schedular is loaded + **value of "quantum of time"**
#
# >~ memo ~ \
# The value of quantum time tells how often the scheduler will be executed
# 1. Interval clock time
# 2. When quantum of time has elapsed
#   * PIC interupts the CPU
#   * Starts executing the scheduler code ← Preemptive Multi-Tasking
#
# >**Context Switching** \
# When PIC interrupts the CPU for scheduling, before changing the IP registers of CPU to @ of scheduler, it copies an exact duplicate of all CPU registers values: Context into RAM, at a reserved, known location owned by Kernel \

# %% [markdown]
# **Schedular** \
# the concept of scheduling makes it possible to have computer multitasking with a single central processing unit (CPU) \
#
# The context of schedular is restored in the CPU registers \
# A ressource allocation algorithm is at the heart of the schedular \
# ← It will decide which process runs next \
# A few possible input parameters
# * Priority associated
# * Total CPU time
# * Average CPU time
# * Frequency on I/O wait
#
# The [schedular](https://en.wikipedia.org/wiki/Scheduling_(computing)) should (ideally) make its decision before the next quantem of time. Otherwise, it will be halted by the PIC! \
# Proof that a computer(one CPU) runs only one process at a time! \
#
# Core = ALU \

# %% [markdown]
# ![link text](https://upload.wikimedia.org/wikipedia/commons/c/cb/Pipeline%2C_4_stage.svg)

# %% [markdown]
# CPU cores \
# Modern CPU with large pipeline \
# 8 Cores 16 Logical Processors ← This is not true \
# They use the multiple pipeline \
# [Hyper-threading](https://en.wikipedia.org/wiki/Hyper-threading) - Schedular fills all slots
#
# 70 modern operating system - Unix \
# Unit of execution → `thread` \
# one thread dedicated to mouse \
# one thread dedicated to the color \
# one thread dedicated to movement \
# If you know how to code in multi-thread way, you can separate the processing unit \
# ← Really, really important since we can ease the \
# Scheduler itself is the thread of Kernel \
# One particular thread deal with the scheduling mechanism
# \
# Ex)Chrome is multi-process within each, multi-threaded
#
# **What is being scheduled?** \
# Since UNIX schedulers have been designed to schedule `threads`(and not whole processes)
#
#
#
# **Process and Threads** \
# The process if a "logical umbrella" of a program(past initial launch) \
# Meta(About) Data: PPID(Parent Process ID ): 250(the one who forked "you") \
# One Process: At least one thread \
#
# \
#
# All threads of a given process fx share the memory space of $T_0, T_1, T_2,... T_n \in P_x$ \
# Data in all T_n are accessible to one another without IPC Kernel call \
#
# What's happening when a massive slow down is user-visible? \
# - Level of ressources utilisation
#  * Many processes: RAM usage increases (disjoint from CPU usage)
#  * A process not responsive to kernel signal (go to sleep) → slow due to a blocking I/O
#
#
#  For K Bomb \
#  Overflow the maximum value of [`PID`](https://en.wikipedia.org/wiki/Process_identifier#:~:text=In%20computing%2C%20the%20process%20identifier,uniquely%20identify%20an%20active%20process.) \
#
#
# Schedular itself is thread of kernel \
# It's one particular kernel which deals with the particular kernel \
# Chrome is multi threads multi processes in each tab \
# Chrome has its own sheduling system \
# Photoshop is its own scheduar due to the complexity of the program

# %% [markdown]
# **Modern Operating System** \
# A story of UNIX \
# Early 70's: Mainphone system
# IBM OS: VMS, MWS, RS/400 \
# Made to time-share with multiple users　\
# Brian Kernighan  & Ritchie: (Bell) Design of Unix

# %% [markdown]
# IBM owns the compliers to COBOL(Common Business Oriented Language)←Management & FORTRAN \
# COBOL is very wordy \
# FORTRAN is created in numerical application, the fastest execution language
# ※You need to pay to IBM to use these languages \
# Creation of the C programming language ←Open Sourced \
#
# [Fundamentals of UNIX]
# * Multi-user system: user accounts
#  - **root user account: system super administration**
#  - **All privileded to root**
# * Preemptive multi Testing schedular (H/W with PIC)
# * Unified, Standardised Input/Output system at kernel level
#
# the UNIX I/O principles \
#
# There are "Standard Fives"(at kernel level): \
# STDIN: Standard Input \
# STDOUT: Standard Output \
# STDERR: Standard Error \
# Standard Files get connected to devices \
# All "reads" are done via STDIN, STDOUT, STDERR

# %% [markdown]
# The UNIX file system design \
# Only one filesystem
# Only one root of filesystem

# %% [markdown]
# **Virtualisation**

# %% [markdown]
# ##Day 3

# %% [markdown]
# Two types of HyperVisors \
# * Built-in a "full" OS
#  * Host OS Kernel + OS subsystem + HyperVision Layer
# * Hypervision OS as main OS over hardware
#
# Victealisation and Main Memory Management \
# RAM Memory + Requires \
#
# Dealing with RAM offsets in VM
# 1. Software-based: the Hypervision Kernel must intercept every RAM I/O of all VM　and rebase the locations　←　SLOW
# 2. Hardware: CPU is equipped with specific compute circuits + ragisters to rebase in {} ← FASTER(almost as fast as one os on machine)
#
# Make sure that VT-x is "on" before "computer system" next week \
#
# Networking
# The plain of{} telephone \
# PSTN: Public Switched Telephone Network \
#
# [`PSTN`](https://en.wikipedia.org/wiki/Public_switched_telephone_network) \
# Electric current + a copper wine \
#
# In a huge network of phones (across a country) with millions of phones \
#
# How does this electic circuit is created? \
#
# **Rooting the flow of payload**
#
# In 1920's in USA \
# NYC $ →_{phone}$ San Francisco \
# NYC phones an operator at a central Exchange \
# wires from home/office to closest Exchange \

# %% [markdown]
# Basic Terms \
# `Switching`: All required I lines cannot exist at a single point of home \
# `Provisionning`: To a minimum necessary capacity maximise its use via switching \
# **If under provisionning happens a new flow of payload cannot happen** \
# [`Payload`](https://en.wikipedia.org/wiki/Payload_(computing)): Data need to be exchanged by community parties\
# `Router Exchange`: Particular mode of the network "aware" on router to move the payload to another Exchange location router

# %% [markdown]
# From PSTN to Internet \
# Internet: Inter-Connection of networks \
# **Multiple networks are routed** \
# ~ Question ~
# > Why was the principle of Internet created?

# %% [markdown]
# ~~
# >If a nuclear bomb is dropped on Chicago \
# Federal is east-bond \
# and wan to communicate with San Francisco \
#
# In the PSTN, the "ROUTING TABLES" are **statically** defined, depending on wiriing between exchange \
# During the journey of the payload, each **hop** to the next exchange is dynamically assessed to **the next best available route** \
# Software is required → Transmission control protocol: [`TCP`](https://searchnetworking.techtarget.com/definition/TCP#:~:text=TCP%20(Transmission%20Control%20Protocol)%20is,of%20data%20to%20each%20other.)\
#
# Protocole? \
# How shoud I send my payload
# party to be able to
# * "decode" the content
# * Make sure that the connect \
#
# The Postal Service \
# Mr(Ms SMITH) 10 Deconing Street ←\
# London → Meta Data Definition \
# A "good" protocol defines well-structured \
# meta- data to
# * Identify exchanging parties IP(Internet Protocol)
# * Control the flow of payloads TCP
#
# The consequence of any networking protocol \
# Supplementary data added to the actual payload \
# The payload is ENVELOPED by meta-data \
#
# TCP/IP add ~ 20/25% of metadata with payload respect \
# Encryption adds TCP/IP much later \

# %% [markdown]
# Consequences of Pachetisation + Roating next best route \
# All packets maching the initial payload take the same routes \
# In [ICP](https://en.wikipedia.org/wiki/Internet_Cache_Protocol) protocol, the recepient mush acknowledge delivery of each packet to Sender if a packet is missing → Sender receives with x attempts \
# Above x → Failed Transmission \
#
# [UDP](https://en.wikipedia.org/wiki/User_Datagram_Protocol): User Datagram Protocol \
# Packet rouled network with next best alternative route \
# Sender sends pachet once and for all with no acknowledgement
# If recipient doesn't receive pucket lost \
#
# Only with payload exchange consistency is not required \
#
# [IP](https://en.wikipedia.org/wiki/Internet_Protocol): Internet Protocol \
# Addresses a device over a network \
# An IP-embed network component
# * Subset Mark: 255, 255, 255, 0 \
#
# IPv4(most common) \
# All addresses are 32 mashed values \
# Subnet must tells which bus of @ may vary \
# 192 168 10 120 wants to send data to another device at : 192.168.10.130 \
# Another device at: 255, 255, 255, 0 \
#                 $\not = 192 $
#
# IP Address need to be individually unique

# %% [markdown]
# ## Day 4

# %% [markdown]
# Algorithmics \
#
# Computer Science is science but also a lot of trends \
# Knowledge of Programming Language is the Knowledge of Syntax \
# But...
# > It's not Science
#
# Computer Science is branch of the Advanced Mathmatics \
# How do we design and analyze the Algorithm?  \
#
# > Before programming, there's a paramount phase: **Analysis & Design** \
#
# Analysis & Design \
# -Building a House- \
#
#
# Analysis:
# >**What** do we want to obtain? \
# Human-intensive phase→ Report describing requirements \
#
# Design:
# >How do I achieve this goals? \
#  Output set of blueprints
#
# \
#
#  After Analysis & Design \
#
#  Implementation:
#  > Coding, Constructing, ... **According to blueprints** \
#
# for IT:
# > Testing phase: Integration testing, [**Unit testing**](https://en.wikipedia.org/wiki/Unit_testing#:~:text=Unit%20tests%20are%20typically%20automated,an%20individual%20function%20or%20procedure.), see PM \
# > Acceptance & Delivery: against requirements & blueprints
#
# Sometimes... \
# You need to pick up pen and paper. \
# How are you gonna approach the problem??
#
# \
#
# The Algorithmic Language([`Pseudo Code`](https://en.wikipedia.org/wiki/Pseudocode)) \
#
# * Programming the language for "instructing" a Turing Machine
# * Completely independent of an Actual Programming Language **but close enough to be converted**

# %% [markdown]
# The factorial Algorithm \
# Environment(of Algorithm) \
# Input Variables/Parameters \
#
# $n:$ integer $\geq 0 $ Constraint on input data
#
# Output Variables:
# result: integer $\geq 1$  iff n $\geq 0$
# undefined if n < 0

# %%
def factorial_(n: int):
  if n<0:
    print("Input error")
  else:
    value = 1
    for i in range(n, 1, -1):
      value = i*value
    return value

# %%
for i in range(10):
  print(factorial_(i))
# Out:
# 1
# 1
# 2
# 6
# 24
# 120
# 720
# 5040
# 40320
# 362880

# %% [markdown]
# The Algorithm Design \
# BEGIN
#
# If algorithm analysis is based on a math formula \
# n! = n × (n -1) ×...×1 \
# iff n>0 \
# if n=0 → 0! =1 \
# if n <0  n!→　$ \emptyset $ \
#
# The Algorithm Design = for comparisons \
# If n = 0 then \
# result ←　１ (Sets the value) \
#
# Else \
#   If n<0 then \
#   result ← NaN(Not a Number) \
#  Else
#
# ~ memo ~
# >Every model you produce can never be parfectly mach with the reality \
# Everytime you close to the reality, more inconsistency
#
# Liers Paradox \
#
# **Recursive** is mental tricky since it hides the iterative process \
#
# Two types \
#
# By example \
#
# ・  The "factorial" type: Countable Iteration \
# **For loop with "loop variabless" counting number of iterations** \
# ・　As long as a value is over under a threshold \
# **→ Fulfill a BOOLEAN condition** → While Loop
#
# While Loop is satisfying or desatisfying the condition, some programming languages dont have while loop
#
# Python loop is not standard interative loop
#
# For Loop in Python is very different from For Loop in Other Programming Languages

# %%
def factorial_(n):
  result = 1
  if n == 0:
    return 1
  else:
    if n<0:
      return NaN
    else:
      for i in range(n, 2, -1):
        result = result*i
      return result

# %%
factorial_(1)
# Out:
# 1

# %% [markdown]
# Fortran, i, j is the for variable \
#
# f(n) = n! \
# n is a formal parameter

# %% [markdown]
# ~ Excercise ~ \
# Analyse & Design the following \
# $g(x, n) = x^n$ \
# with $x \in R$
# $n \in N$ \
# and when n=0 \
# $g(x, 0) = 1 \forall x \in R$

# %%
def g(x, n):
  if n>0:
    if n ==0:
      return 1
    else:
      return x**n

# %% [markdown]
# ```
# BEGIN
# if n is natural number and x is real number, then
#   if n is 0, then
#    result ← 1
#   else
#     result x to the power n
# ```

# %% [markdown]
# When Pseudocode, \
# Try to write with the actual numbers \
#
# Write the pseudocode is where we starts \
# Then, programming language will follow.
#
# Recursive \
# If n<0 then \
# n ← n*(-1)

# %% [markdown]
# time series of causes of observed phenomenon \
# Classification program
# Time component

# %% [markdown]
# ```
# BEGIN
# IF n = 0 THEN
#   result ← 1
# ELSE
#   IF x = 0 THEN
#     result ← 0
#   ELSE
#     result　←1
#     FOR i ← 1 to abs(n) STEP 1
#      result ← result*x
#     END FOR
#     IF n < 0 THEN
#       result ← 1/result
#     END IF
#   ENDIF
# ENDIF
# RETURN result
# END
# ```

# %% [markdown]
# How can we test the Algorithm ? \
# TRACING / UNIT TESTING(in programming) \

# %% [markdown]
# ![Screen Shot 2020-10-19 at 16.22.35.png](data:image/png;base64,...)![Screen Shot 2020-10-19 at 16.22.25.png](data:image/png;base64,...)

# %% [markdown]
# ```
# BEGIN
#   IF n < 0 THEN
#     result ← NaN
#   ELSE
#     result ← 1 ←Initialization required & saves a conditional test (for n = 0)
#     FOR i ← n TO 2 step -1
#       result ← result*i
#     END FOR
#   ENDIF
#   return result
# END
# ```

# %% [markdown]
# Sum and average of a set of n integers?
# Away of integers
# → Always are meant to be continuous in RAM \
# Indexed at base 0 \
# Unary operator "accessor": [] \
# MyIntAray[2] →3rd element of array \
# RAM representation by CPU "WORD", i.e. the size of registers \
#
#
# ```
# sum of array
#   mysum ← 0
#   FOR i ← 0 to Length(myArray) -1
#     mysum ← mysum + myArray[i]
#   END FOR
#   myAVg ← mySum/ Length(myArray)
# ```
# C language cannot know the length of array by len \
# Array doesnt exist in C \

# %% [markdown]
# C is strongly typed language \
# ~ features ~
# > Programmer must set the type of variable \
#
# > Main() \
# No input parameter →() \
#  +main return an int → integer \
#  the program point of entry
#
# %ERRORLEVEL% \
# dir return 1 when there is an error \
# dir return 0 when there is no error

# %%
a = 2
b = 4

# %%
def swap(a, b):
  a = b
  b = a
  return a, b

# %%
import numpy as np
A = np.array([1,2,3,4,5])
B = np.array([6,7,8,9,10])

# %%
swap(A, B)
# Out:
# (array([ 6,  7,  8,  9, 10]), array([ 6,  7,  8,  9, 10]))

# %%
A
# Out:
# array([1, 2, 3, 4, 5])
