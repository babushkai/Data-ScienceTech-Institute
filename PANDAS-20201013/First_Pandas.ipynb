# %%
import pandas as pd
import numpy as np

# %%
# insert your own path to bank data
# df is the object inheriting all the methods from pandas
df = pd.read_csv('bank.csv', sep = ";")
df.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
df.describe()
# Out:
#                age       balance          day     duration     campaign  \
# count  4521.000000   4521.000000  4521.000000  4521.000000  4521.000000
# mean     41.170095   1422.657819    15.915284   263.961292     2.793630
# std      10.576211   3009.638142     8.247667   259.856633     3.109807
# min      19.000000  -3313.000000     1.000000     4.000000     1.000000
# 25%      33.000000     69.000000     9.000000   104.000000     1.000000
# 50%      39.000000    444.000000    16.000000   185.000000     2.000000
# 75%      49.000000   1480.000000    21.000000   329.000000     3.000000
# max      87.000000  71188.000000    31.000000  3025.000000    50.000000
#
#              pdays     previous
# count  4521.000000  4521.000000
# mean     39.766645     0.542579
# std     100.121124     1.693562
# min      -1.000000     0.000000
# 25%      -1.000000     0.000000
# 50%      -1.000000     0.000000
# 75%      -1.000000     0.000000
# max     871.000000    25.000000

# %%
df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 0     cellular   19   oct        79         1     -1         0  unknown  no
# 1     cellular   11   may       220         1    339         4  failure  no
# 2     cellular   16   apr       185         1    330         1  failure  no
# 3      unknown    3   jun       199         4     -1         0  unknown  no
# 4      unknown    5   may       226         1     -1         0  unknown  no
# ...        ...  ...   ...       ...       ...    ...       ...      ...  ..
# 4516  cellular   30   jul       329         5     -1         0  unknown  no
# 4517   unknown    9   may       153         1     -1         0  unknown  no
# 4518  cellular   19   aug       151        11     -1         0  unknown  no
# 4519  cellular    6   feb       129         4    211         3    other  no
# 4520  cellular    3   apr       345         2    249         7    other  no
#
# [4521 rows x 17 columns]

# %%
df.describe().round(2)
# Out:
#            age   balance      day  duration  campaign    pdays  previous
# count  4521.00   4521.00  4521.00   4521.00   4521.00  4521.00   4521.00
# mean     41.17   1422.66    15.92    263.96      2.79    39.77      0.54
# std      10.58   3009.64     8.25    259.86      3.11   100.12      1.69
# min      19.00  -3313.00     1.00      4.00      1.00    -1.00      0.00
# 25%      33.00     69.00     9.00    104.00      1.00    -1.00      0.00
# 50%      39.00    444.00    16.00    185.00      2.00    -1.00      0.00
# 75%      49.00   1480.00    21.00    329.00      3.00    -1.00      0.00
# max      87.00  71188.00    31.00   3025.00     50.00   871.00     25.00

# %%
df.describe(exclude=[np.number])
# Out:
#                job  marital  education default housing  loan   contact month  \
# count         4521     4521       4521    4521    4521  4521      4521  4521
# unique          12        3          4       2       2     2         3    12
# top     management  married  secondary      no     yes    no  cellular   may
# freq           969     2797       2306    4445    2559  3830      2896  1398
#
#        poutcome     y
# count      4521  4521
# unique        4     2
# top     unknown    no
# freq       3705  4000

# %%
df.poutcome.describe()
# Out:
# count        4521
# unique          4
# top       unknown
# freq         3705
# Name: poutcome, dtype: object

# %%
sum(df.poutcome=='unknown')
# Out:
# 3705

# %%
df.poutcome.unique()
# Out:
# array(['unknown', 'failure', 'other', 'success'], dtype=object)

# %%
df[df.poutcome=='unknown']
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# 7      39     technician  married  secondary      no      147     yes   no
# 8      41   entrepreneur  married   tertiary      no      221     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4513   49    blue-collar  married  secondary      no      322      no   no
# 4515   32       services   single  secondary      no      473     yes   no
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 0     cellular   19   oct        79         1     -1         0  unknown  no
# 3      unknown    3   jun       199         4     -1         0  unknown  no
# 4      unknown    5   may       226         1     -1         0  unknown  no
# 7     cellular    6   may       151         2     -1         0  unknown  no
# 8      unknown   14   may        57         2     -1         0  unknown  no
# ...        ...  ...   ...       ...       ...    ...       ...      ...  ..
# 4513  cellular   14   aug       356         2     -1         0  unknown  no
# 4515  cellular    7   jul       624         5     -1         0  unknown  no
# 4516  cellular   30   jul       329         5     -1         0  unknown  no
# 4517   unknown    9   may       153         1     -1         0  unknown  no
# 4518  cellular   19   aug       151        11     -1         0  unknown  no
#
# [3705 rows x 17 columns]

# %%
df[(df.poutcome=='unknown') & (df.balance > 500)]
# Out:
#       age          job   marital  education default  balance housing loan  \
# 0      30   unemployed   married    primary      no     1787      no   no
# 3      30   management   married   tertiary      no     1476     yes  yes
# 10     39     services   married  secondary      no     9374     yes   no
# 12     36   technician   married   tertiary      no     1109      no   no
# 13     20      student    single  secondary      no      502      no   no
# ...   ...          ...       ...        ...     ...      ...     ...  ...
# 4508   42       admin.   married    unknown      no      642     yes  yes
# 4509   51   technician   married   tertiary      no     2506      no   no
# 4510   36   technician  divorced  secondary      no      566     yes   no
# 4511   46  blue-collar   married  secondary      no      668     yes   no
# 4512   40  blue-collar   married  secondary      no     1100     yes   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome    y
# 0     cellular   19   oct        79         1     -1         0  unknown   no
# 3      unknown    3   jun       199         4     -1         0  unknown   no
# 10     unknown   20   may       273         1     -1         0  unknown   no
# 12    cellular   13   aug       328         2     -1         0  unknown   no
# 13    cellular   30   apr       261         1     -1         0  unknown  yes
# ...        ...  ...   ...       ...       ...    ...       ...      ...  ...
# 4508   unknown   16   may       509         2     -1         0  unknown   no
# 4509  cellular   30   nov       210         3     -1         0  unknown   no
# 4510   unknown   20   may       129         2     -1         0  unknown   no
# 4511   unknown   15   may      1263         2     -1         0  unknown  yes
# 4512   unknown   29   may       660         2     -1         0  unknown   no
#
# [1690 rows x 17 columns]

# %%
df.y.describe()
df.y.dtype
# Out:
# dtype('O')

# %%
df[(df.poutcome=='unknown') & (df.y == 'no')].shape
# Out:
# (3368, 17)

# %%
df.shape
# Out:
# (4521, 17)

# %%
df.y.value_counts()
# Out:
# no     4000
# yes     521
# Name: y, dtype: int64

# %%
# normalize over all values.
pd.crosstab(df.y, "freq", normalize=True)
# Out:
# col_0     freq
# y
# no     0.88476
# yes    0.11524

# %%
t = pd.crosstab(df.y, "freq", normalize=True)
t.plot.bar()

# %%
t.plot(kind = "bar")

# %%
(t * 100).plot(kind = "bar")

# %%
t.plot.pie(subplots=True, figsize = (6, 6))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001AF6F2A5898>],
#       dtype=object)

# %%
df.corr() # meaningless in our case
# Out:
#                age   balance       day  duration  campaign     pdays  previous
# age       1.000000  0.083820 -0.017853 -0.002367 -0.005148 -0.008894 -0.003511
# balance   0.083820  1.000000 -0.008677 -0.015950 -0.009976  0.009437  0.026196
# day      -0.017853 -0.008677  1.000000 -0.024629  0.160706 -0.094352 -0.059114
# duration -0.002367 -0.015950 -0.024629  1.000000 -0.068382  0.010380  0.018080
# campaign -0.005148 -0.009976  0.160706 -0.068382  1.000000 -0.093137 -0.067833
# pdays    -0.008894  0.009437 -0.094352  0.010380 -0.093137  1.000000  0.577562
# previous -0.003511  0.026196 -0.059114  0.018080 -0.067833  0.577562  1.000000

# %%
df.balance.cov(df.age)
# Out:
# 2668.0427294552665

# %%
# Visualise covariates two by two
from pandas.plotting import scatter_matrix
scatter_matrix(df, alpha=0.2, figsize=(10, 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001AF704F42B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF704D0B70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF70517E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF70548438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF7057A9E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF705ADF98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF705E8588>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001AF70619B70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF70619BA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF706886D8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF706BAC88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF706F8278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF70726828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF7075CDD8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001AF707983C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF707C7978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF707F9F28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF71806518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF71838AC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF718740B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF718A6668>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001AF718D8C18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF71917208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF719497B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF71979D68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF719B8358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF719E7908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF71A19EB8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001AF71A574A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF71A87A58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF71AC7048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF71AF75F8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF71B25908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF71B58EB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF71B964A8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001AF71BC5A58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF71C04048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF71C355F8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF71C64BA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF71CA4198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF71CD3748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF71D06CF8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001AF71D452E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF71D73898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF71DA7E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF71DE3438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF71E139E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF71E46F98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF71E84588>]],
#       dtype=object)

# %%
# If you are familiar with PDE, you can estimate each variable distribution with 'kde' method
scatter_matrix(df, alpha=0.2, figsize=(10, 10), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001AF7413A6D8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF742115C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF7423EB70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF74279160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF742A9710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF742D6CC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF743102B0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001AF74340898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF743408D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF743B1400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF743E29B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF74414F60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF74451550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF74483B00>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001AF744C10F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF744F16A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF74523C50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF74561240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF745927F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF745C3DA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF74600390>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001AF74631940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF74665EF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF746A04E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF746D0A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF74711080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF74741630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF7476FBE0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001AF747AF1D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF747DF780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF74812D30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF74851320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF748808D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF748B5E80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF748EF470>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001AF74922A20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF74954FD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF7498F5C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF749C2B70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF749FF160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF74A31710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF74A62CC0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001AF74A9F2B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF74ACE860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF74B02E10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF74B40400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF74B6F9B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF74BA1F60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF74BDE550>]],
#       dtype=object)

# %%
# Compare qualitative variables
pd.crosstab(df.education, df.y)
# Out:
# y            no  yes
# education
# primary     614   64
# secondary  2061  245
# tertiary   1157  193
# unknown     168   19

# %%
# margins will add subtotals
pd.crosstab(df.education, df.y, margins = True)
# Out:
# y            no  yes   All
# education
# primary     614   64   678
# secondary  2061  245  2306
# tertiary   1157  193  1350
# unknown     168   19   187
# All        4000  521  4521

# %%
# Normalize margin values
pd.crosstab(df.education, df.y, margins = True, normalize = True)
# Out:
# y                no       yes       All
# education
# primary    0.135811  0.014156  0.149967
# secondary  0.455873  0.054192  0.510064
# tertiary   0.255917  0.042690  0.298607
# unknown    0.037160  0.004203  0.041363
# All        0.884760  0.115240  1.000000

# %%
# normalize over each row
pd.crosstab(df.education, df.y, margins = True, normalize = 'index')
# Out:
# y                no       yes
# education
# primary    0.905605  0.094395
# secondary  0.893755  0.106245
# tertiary   0.857037  0.142963
# unknown    0.898396  0.101604
# All        0.884760  0.115240

# %%
# normalize over each column
pd.crosstab(df.education, df.y, margins = True, normalize = 'columns')
# Out:
# y               no       yes       All
# education
# primary    0.15350  0.122841  0.149967
# secondary  0.51525  0.470250  0.510064
# tertiary   0.28925  0.370441  0.298607
# unknown    0.04200  0.036468  0.041363

# %%
t_ = pd.crosstab(df.education, df.y, margins=True, normalize = 'index')
t_.plot()

# %%
t_.plot.bar()

# %%
ta_ = pd.crosstab(df.education, df.y, margins=True, normalize = 'columns')
ta_.plot.bar()

# %%
df.groupby("y").mean()
# Out:
#            age      balance        day    duration  campaign      pdays  \
# y
# no   40.998000  1403.211750  15.948750  226.347500  2.862250  36.006000
# yes  42.491363  1571.955854  15.658349  552.742802  2.266795  68.639155
#
#      previous
# y
# no   0.471250
# yes  1.090211

# %%
balanceGroup = [df.balance[df.y == s] for s in list(df.y.unique())]
balanceGroup[1]
# Out:
# 13       502
# 30      4189
# 33      2536
# 34      1235
# 36       229
#         ...
# 4494     668
# 4503     362
# 4504    1080
# 4505     620
# 4511     668
# Name: balance, Length: 521, dtype: int64

# %%
df.hist(column = "balance", by = "education")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001AF73B06E80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF73B45550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001AF73B756D8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AF73BA2C88>]],
#       dtype=object)

# %%
df.balance.describe()
# Out:
# count     4521.000000
# mean      1422.657819
# std       3009.638142
# min      -3313.000000
# 25%         69.000000
# 50%        444.000000
# 75%       1480.000000
# max      71188.000000
# Name: balance, dtype: float64

# %%
df.education.describe()
# Out:
# count          4521
# unique            4
# top       secondary
# freq           2306
# Name: education, dtype: object

# %%
df.boxplot()

# %%
df.boxplot(column=['balance'])

# %%
df[df.balance > 40000]
# Out:
#       age           job  marital education default  balance housing loan  \
# 2989   42  entrepreneur  married  tertiary      no    42045      no   no
# 3700   60       retired  married   primary      no    71188      no   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 2989  cellular    8   aug       205         2     -1         0  unknown  no
# 3700  cellular    6   oct       205         1     -1         0  unknown  no

# %% [markdown]
# Example method for supressing outliers
# 1. Arrange your data in ascending order
# 2. Calculate Q1 ( the first Quartile)
# 3. Calculate Q3 ( the third Quartile)
# 4. Find IQR = (Q3 - Q1)
# 5. Find the lower Range = Q1 -(1.5 * IQR)
# 6. Find the upper Range = Q3 + (1.5 * IQR)

# %%
Q1 = df.quantile(0.25)
Q1
# Out:
# age          33.0
# balance      69.0
# day           9.0
# duration    104.0
# campaign      1.0
# pdays        -1.0
# previous      0.0
# Name: 0.25, dtype: float64

# %%
Q3 = df.quantile(0.75)

# %%
IQR = Q3 - Q1
print(IQR)
# Out:
# age           16.0
# balance     1411.0
# day           12.0
# duration     225.0
# campaign       2.0
# pdays          0.0
# previous       0.0
# dtype: float64

# %%
df_ = df[~((df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))).any(axis=1)]
print(df.shape, df_.shape)
# Out:
# (4521, 17) (2803, 17)

# %% [markdown]
# Exercise :
#  - explore how the different variables are related
#  - which problems must be solved before further analysis
#  - design a fine-grained function to supress outliers
