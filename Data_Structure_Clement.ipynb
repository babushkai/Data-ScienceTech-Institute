# %% [markdown]
# 1. System Architecture \
# a. Hardware \
#   i. Von Neumann \
# b. Scheduling \
# c. Filesystem \
#
# 2. Windows \
# a. Dos command \
# b. Powershell \
# c. Setup a webserver
#
# 3. Linux \
# a. Linux architecture \
# b. Bash
#
# 4. Web Server(Linux) \
# a. Security \
# b. Database \
# c. Webserver \
# d. SSL \
#
# 5. Introduction to Docker

# %% [markdown]
# 1. System Architecture
#
# RAM
# - No persistance
# - Fast access
#
# Hard Disk([`SWAP`](https://www.enterprisestorageforum.com/storage-hardware/memory-swapping.html#:~:text=Memory%20swapping%20makes%20use%20of,to%20extend%20available%20system%20resources.&text=Memory%20swapping%20is%20a%20computer,random%20access%20memory%20(RAM)))
# - Persistance
# - Slow access
#
# When RAM is filled, the data goes to Hard Disk so the program still works, but very slow \
#
# Windows is not made to do the big computation

# %% [markdown]
# Memory block has an address and it's called chunk \
# Virtually located is not the same as physically located \
#
# [`Fat 16`](https://en.wikipedia.org/wiki/File_Allocation_Table#FAT16) \
# -  The benefit of FAT16 was the use of smaller clusters, making disk usage more efficient, particularly for large numbers of files only a few hundred bytes in size. \
#
# Fat 32 \
# [`NTFS`](https://en.wikipedia.org/wiki/NTFS)
# -  proprietary journaling file system developed by Microsoft

# %% [markdown]
# [`MD5`](https://en.wikipedia.org/wiki/MD5) \
# test1 \
# test2 \
# When there is the collision(different word but same hash) between two passwords, it breaks the password \
# A + B 65/66 \
# B + A 66/65 \
# A+ A 666/5 \

# %% [markdown]
# 1 KB \
# 1024 x 1byte \
# 1000 x 1byte \
#
#
# and \
# 1 and 1 =1 \
# 1 and 0 = 0 \
# 0 and 1 = 0 \
# 0 and 0 = 0 \
#
# or \
# 1 or 1= 1 \
# 1 or 0 = 1 \
# 0 or 1 = 1 \
# 0 or 0 = 0 \
#
# nor \
# 1 nor 1 = 0 \
# 1 nor 0 = 1 \
# 0 nor 1 = 1 \
# 0 nor 0 = 0 \
#
# 128 ←　Unsigned: -127 to 127 \

# %% [markdown]
# **ALU** \
# bit 0/1 -binary \
# byte 8 bit \
#
#
# > 64 32 16 8 4 2 1 \
# > 0 0 0 0 0 0 0 = 32 \
# > 1 0 0 0 0 0 0 = 64 \
# if 1111111, max*2 -1

# %% [markdown]
# LSB Less Significant Bytes ex)0 \
# MSB Most Significant Bytes ex)128

# %% [markdown]
# GPU is less flexible \
# ← Matrix Calculation \
# Parallel Calculation \
# 40 cores of CPU is 6 cores of GPU
#
# Constructer \
# AMd is less flexible \
#
# Your network is bad \
# How the data is worked to figure out where the bug comes from

# %% [markdown]
# Hexadecimal \
# $ 13_{16} $ → $ 1g_{10} $ \
# 0123456789ABCDEF \
# 1F = 31 = 16 + 15 \
# FF = 255 = (15x 6) + 15 = 255

# %% [markdown]
# **Network**
#
# Seven Layers
#
# Presentation and Session is not really related

# %% [markdown]
# ![network.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# [`WireShark`](https://en.wikipedia.org/wiki/Wireshark) \

# %% [markdown]
# ![Wireshark.png](data:image/png;base64,...)

# %% [markdown]
# ~ Cyber Attack ~ \
# [`Denial of Service Attack`](https://en.wikipedia.org/wiki/Denial-of-service_attack) \
# - Not working anymore
#
# [`Mirai`](https://en.wikipedia.org/wiki/Mirai_(malware)) \

# %% [markdown]
# [`Root Kit`](https://en.wikipedia.org/wiki/Rootkit) \
# Small program to access to superadmin \
#
# Injection \

# %% [markdown]
# [`Man in the middle man`](https://en.wikipedia.org/wiki/Man-in-the-middle_attack)

# %% [markdown]
# [`Social Engineering`](https://en.wikipedia.org/wiki/Social_engineering_(security))

# %% [markdown]
# Injection \
# Select Username \
# From User \
# Where Username = username

# %% [markdown]
# Excercise \
# 1) Give the execution order for FIFO \
# A)P2→P4→P3→P5→P1 \
# **A)** P1P2P3P4P5 \
# 2) Give the execution order of shortest remaining time \
# A)P2→P4→P3→P5→P1 RIGHT \
#
# 3) Give the execution order for Priority scheduler \
# Highest to Lowest \
# A)P2→P4→P５→P1→P3 \
# A)P1, P3, P5, P2, P1 \
#
# 4) Assuming a 2 clock process give draw the execution table allowing each process to be terminating \
# A)??
#
# FIFO)P3→P4→P2→P1→P5 \
# A)P1P2P3P4P5P1P5P1P5P1P1 \
# SRT \
# P2P4P3P5P1P5P1P5P1P1P1
# P3→P1→P4→P5→P2

# %% [markdown]
# - FiFo
# - Priority scheduler
# - Pre-emptive \
#
# Multilevel \
# Interactive \
# -
# Backen \
# - \
#
# FiFo \
# First process arrived, first executed Pre-emptive scheduling \
# Highest priority first, with pre-emption

# %% [markdown]
# Short Remninn first \
# The task with the shortest execution time is excuted first \
# Round Robin \
# Execute task with a determined Time before re-queu it

# %% [markdown]
# ## Day2

# %% [markdown]
# Power Shell Script \
# - Pool, for, while, etc... \
# - Conditions: if, elseif, else \
# - variable \
# - extension: \
# PS1 eg: myscript ps1 \
# Run: myscript ps1 \
# Set-Execution Policy Remote Signed

# %% [markdown]
# ## Day3

# %% [markdown]
# 1(root)
# - user
# - var -mww- -log
# - etc
# - bin(binaries)
# - fib
# - tmp
# - boot
# - dev
# - home -user1, -user2
#
# Post + Round: Recovered Files \
# Media: Removable Media \
# Mnt: Temporary mounted Points \
# Opt: Optional Packages \
# Run: Run State file \
# Sbin: Administration binaries \
# Srv: Service Data \
# /root: Home Lorder for Root \
#
# Some of the files are not very important \

# %% [markdown]
# [`Dual boot`]() \
# Window and Linux \
# **It is not recommended** \
#
# To increase the [`swap`](https://www.slideshare.net/transweb/swapping-computer-science) to work on the neural networks \
# You will be run out of your memory(RAM), you can use the other partitions as the external memory. \
# 200GB RAM is maximum \
# 128GB \

# %% [markdown]
# Root: Superadmin \
# User: Regular user \
# Guest: Anonymous User \

# %% [markdown]
# Home - Nameofuser \
# User with Home Folder \
# Application user \
# Group: \
# User1 -> User1 \
# Web, admin \
# Everytime you create user, you create owner and group of user \
#
# **R**ead/ **W**rite/ E**x**ecution access \

# %% [markdown]
# ![Data Structure.png](data:image/png;base64,...)

# %% [markdown]
# [`Chmod command`](https://chmodcommand.com/chmod-640/) \
# chown(Change Owner) nameuser nameFile
# chgrp(Change group) namegroup name file \
# chmodo = rwx, g =rw, a=r \
# u+x \
# u+rwx \
# u-r \
# chmod -R ← Recursive means all of them \
# rm -R  ← Recursive

# %% [markdown]
# Sudo \
# Sudo nano/etc/nginx/conf \
# sudoe \
# Debian, Sudoeis, ubuntu, sudo \
#
# /dev/null
#
# Source \
# apt-update \
# upgrade if the update is available in some packages \
# apt upgrade name of package \
# apt install name of the package \
# wget url location \
# chmod u+x

# %% [markdown]
# Debian is for server \
# Ubuntu is for user \
# Ubuntu Kernel uses Debian kernel and vice versa \
# CMD1 && \
# CMD1/CMD2

# %% [markdown]
# && → Wait previous command success to run the next \
# i → Run command one after one without checking the success of the previous one \
# l →　Pipe send result of the previous to the next one
